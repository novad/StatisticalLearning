# %%
library(MASS)

attach(Boston)

# (a)
dim(Boston)
# there are 506 observations (columns), and 14 variables (rows)

# (b)
pairs(Boston)
# Out:
# [1] 506  14
# plot without title

# %% [markdown]
# ## (c)
#
# Only by looking at the plots, we can see some possible associations of some variables with 'crim' (per capita crime rate by town).
#
# For instance noticable higher rates on average for the lowest values of zn(proportion of residential land zoned for lots over 25,000 sq.ft.)
#
# We see interesting associations that could imply higher crime rates, like higher values of age,
#
# Lower employment rates ahve a significant increase of crime rate.
# There seems to be an decrease of crim for higher values of medv

# %% [markdown]
# ## (d)
# We can see a possible association of these predcitors by looking at the scatterplot

# %%
pairs(~crim+tax+ptratio, Boston)
# Out:
# plot without title

# %% [markdown]
# ## (e)
# There are 35 suburbs that bound the Charled river.
# The dummy variable is coded as: 1 if tract bounds river; 0 otherwise

# %%
summary(as.factor(chas))
# Out:
#   0   1
# 471  35

# %% [markdown]
# ## (f)
# The median is 19.05

# %%
median(ptratio)
# Out:
# [1] 19.05

# %% [markdown]
# ## (g)

# %%
row = which.min(medv)

Boston[row, ]
# Out:
#     crim    zn indus chas nox   rm    age dis    rad tax ptratio black lstat
# 399 38.3518 0  18.1  0    0.693 5.453 100 1.4896 24  666 20.2    396.9 30.59
#     medv
# 399 5

# %% [markdown]
# ## (h)

# %%
dim(subset(Boston, rm > 7))
dim(subset(Boston, rm > 8))
# Out:
# [1] 64 14
# [1] 13 14
